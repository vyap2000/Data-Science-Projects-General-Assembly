# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 15px; height: 80px">
#
# # Project 1
#
# ### Building "Pokemon Stay"
#
# ---
# You are an analyst at a "scrappy" online gaming company that specializes in remakes of last year's fads.
#
# Your boss, who runs the product development team, is convinced that Pokemon Go's fatal flaw was that you had to actually move around outside. She has design mock-ups for a new game called Pokemon Stay: in this version players still need to move, but just from website to website. Pokemon gyms are now popular online destinations, and catching Pokemon in the "wild" simply requires browsing the internet for hours in the comfort of your home.
#
# She wants you to program a prototype version of the game, and analyze the planned content to help the team calibrate the design.

# %% [markdown]
# #### Package imports
#
# The pprint package below is the only package imported here, and it's not even strictly required to do any of the project. Printing python variables and objects with pprint can help to format them in a "prettier" way.

# %%
from pprint import pprint 
import pprint

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 1. Defining a player
#
# ---
#
# The player variables are:
#
#     player_id : id code unique to each player (integer)
#     player_name : entered name of the player (string)
#     time_played : number of time played the game in minutes (float)
#     player_pokemon: the player's captured pokemon (dictionary)
#     gyms_visited: ids of the gyms that a player has visited (list)
#
# Create the components for a player object by defining each of these variables. The dictionary and list variables should just be defined as empty; you can use any (correctly typed) values for the others.

# %%
# Class definition for player with a few class methods defined.

class Player(object):
    
    # set counter = 0 for the use of  _count and id(self), count number of players instance created.
    __count = 0         
    
    def _count(cls):
        Player.__count += 1
        return Player.__count  
    
    def id(self):
        return self.__id    
  
    
    def __init__(self, player_id=0, player_name='name', time_played=0.0, player_pokemon={}, gym_visited=[]):
        self.__id = self._count()
        print('Initializing new instance for a new player') 
        
            
    # define a method for adding new player 
    
    def add_new_player (self, player_id, player_name, time_played, player_pokemon, gym_visited):
        self.player_id = player_id
        self.player_name = player_name
        self.time_played = time_played
        self.player_pokemon = player_pokemon
        self.gym_visited = gym_visited
        return [player_id, player_name, time_played, player_pokemon, gym_visited]
    
   
    # method to display player statistic / properties in the class instance created
    
    def print_player_stat (self):
        print ('Player_ID: {}'.format(self.player_id))
        print ('Player_Name: {}'.format(self.player_name))
        print ('Player_Time_Played: {}'.format(self.time_played))
        print ('Player_Pokemon: {}'.format(self.player_pokemon))
        print ('Player_Gym_Visited: {}'.format(self.gym_visited))
        print ('\n')

    # method to display player summary for playerlist dictionary
    
    def summary (self):    
        for keys,values in playerlist.items():
            print('\n','Player',(keys),':')  
            pprint.pprint(values)   
            print('\n')            
                
    # method to add gym location visited
    
    def add_gym_location (self, gym_visited):
        self.gym_visited = self.gym_visited + gym_visited     # Adding gym visited to existing list
        print ('{}'.format(self.player_name),'Gym Visited: {}'.format(self.gym_visited))
    
    
    
    
    #### I wanted to write this class method in place of question 9 but have not got time to complete. #### 
    
    def add_full_pokedex (self, key, name, typec, total, hp, attack, defense, specialattack, specialdefense, speed):  
        self.key=key
        self.name=name
        self.typec=typec
        self.total=total
        self.hp=hp
        self.attack=attack
        self.defense=defense
        self.specialattack=specialattack
        self.specialdefense=specialdefense
        self.speed=speed
                    
        mydict["key"] = self.key
        mydict["name"] = self.name
        mydict["type"] = self.typec
        mydict["total"] = self.total
        mydict["total"] = self.total
        mydict["hp"] = self.hp
        mydict["attack"] = self.attack
        mydict["defense"] = self.defense
        mydict["special_attack"] = self.specialattack
        mydict["special_defense"] = self.specialdefense
        mydict["speed"] = self.speed

        return {key, name, typec, total, hp, attack, defense, specialattack, specialdefense, speed}

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 2. Defining "gym" locations
#
# ---
#
# As the sole programmer, Pokemon Stay will have to start small. To begin, there will be 10 different gym location websites on the internet. The gym locations are:
#
#     1. 'reddit.com'
#     2. 'amazon.com'
#     3. 'twitter.com'
#     4. 'linkedin.com'
#     5. 'ebay.com'
#     6. 'netflix.com'
#     7. 'sporcle.com'
#     8. 'stackoverflow.com'
#     9. 'github.com'
#     10. 'quora.com'
#
# 1. Set up a list of all the gym locations. This will be a list of strings.
# 2. Append two of these locations to your player's list of visited gyms.
# 3. Print the list.

# %%
# Define a list of gym location

gyms = ['reddit.com','amazon.com','twitter.com','linkedin.com','ebay.com','netflix.com','sporcle.com','stackoverflow.com','github.com','quora.com']

# %%
# Empty player instance for calling functions.
player=Player()       

# Create new object instance for player 1 - Adding 2 gym locations
player1=Player()
player1.add_new_player(1,'Vincent',88.8,{},[gyms[6],gyms[3]])

#### Leaving player 2 for later ####

# Create new object instance for player 3 - Adding 2 gym locations
player3=Player() 
player3.add_new_player(3,'Diane',36.9,{},[gyms[2],gyms[8]])

# Create new object instance for player 4 - Adding 2 gym locations
player4=Player()
player4.add_new_player(4,'Timmy',124.6,{},[gyms[4],gyms[7]])
# Out:
# Initializing new instance for a new player
# Initializing new instance for a new player
# Initializing new instance for a new player
# Initializing new instance for a new player
# [4, 'Timmy', 124.6, {}, ['ebay.com', 'stackoverflow.com']]

# %%
# Calling class method "add_gym_location method" to update gym visited for individual player

# player1.add_gym_location([gyms[1],gyms[9]])
# player3.add_gym_location([gyms[3],gyms[5],gyms[0]])
# player4.add_gym_location([gyms[8]])

# %%
# Print player statistic by class method to display instances' attributes. (This is NOT playerlist dictionary but the class instances)

player1.print_player_stat()
player3.print_player_stat()
player4.print_player_stat()
# Out:
# Player_ID: 1
# Player_Name: Vincent
# Player_Time_Played: 88.8
# Player_Pokemon: {}
# Player_Gym_Visited: ['sporcle.com', 'linkedin.com']
#
#
# Player_ID: 3
# Player_Name: Diane
# Player_Time_Played: 36.9
# Player_Pokemon: {}
# Player_Gym_Visited: ['twitter.com', 'github.com']
#
#
# Player_ID: 4
# Player_Name: Timmy
# Player_Time_Played: 124.6
# Player_Pokemon: {}
# Player_Gym_Visited: ['ebay.com', 'stackoverflow.com']

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 3. Create a pokedex
#
# ---
#
# We also need to create some pokemon to catch. Each pokemon will be defined by these variables:
#
#     pokemon_id : unique identifier for each pokemon (integer)
#     name : the name of the pokemon (string)
#     type : the category of pokemon (string)
#     hp : base hitpoints (integer)
#     attack : base attack (integer)
#     defense : base defense (integer)
#     special_attack : base special attack (integer)
#     special_defense : base sepecial defense (integer)
#     speed : base speed (integer)
#
# We are only going to create 3 different pokemon with these `pokemon_id` and `pokemon_name` values:
#
#     1 : 'charmander'
#     2 : 'squirtle'
#     3 : 'bulbasaur'
#
# Create a dictionary that will contain the pokemon. The keys of the dictionary will be the `pokemon_id` and the values will themselves dictionaries that contain the other pokemon variables. The structure of the pokedex dictionary will start like so:
#
#      {
#          1: {
#                  'name':'charmander',
#                  'type':'fire',
#                  ...
#
# The `type` of charmander, squirtle, and bulbasaur should be `'fire'`, `'water'`, and `'poison'` respectively. The other values are up to you, make them anything you like!
#
# Print (or pretty print) the pokedex dictionary with the 3 pokemon.

# %%
pokedex = { 
            1: 
            {'name':'charmander',
            'typecat':'fire',
            'hp':100,
            'attack':101,
            'defense':100,
            'special_attack':101,
            'special_defense':100,
            'speed':100
            },
    
            2: 
            {'name':'squirtle',
            'typecat':'water',
            'hp':100,
            'attack':102,
            'defense':100,
            'special_attack':102,
            'special_defense':100,
            'speed':100
            },
              
            3: 
            {'name':'bulbasaur',
            'typecat':'poison',
            'hp':100,
            'attack':103,
            'defense':100,
            'special_attack':103,
            'special_defense':100,
            'speed':100
            } 
          }

# %%
# pretty print pokedex dictionary with the 3 pokemon.

for keys,values in pokedex.items():
    pprint.pprint(keys)
    pprint.pprint(values)
# Out:
# 1
# {'attack': 101,
#  'defense': 100,
#  'hp': 100,
#  'name': 'charmander',
#  'special_attack': 101,
#  'special_defense': 100,
#  'speed': 100,
#  'typecat': 'fire'}
# 2
# {'attack': 102,
#  'defense': 100,
#  'hp': 100,
#  'name': 'squirtle',
#  'special_attack': 102,
#  'special_defense': 100,
#  'speed': 100,
#  'typecat': 'water'}
# 3
# {'attack': 103,
#  'defense': 100,
#  'hp': 100,
#  'name': 'bulbasaur',
#  'special_attack': 103,
#  'special_defense': 100,
#  'speed': 100,
#  'typecat': 'poison'}

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 4. Create a data structure for players
#
# ---
#
# ### 4.1
#
# In order to maintain a database of multiple players, create a dictionary that keeps track of players indexed by `player_id`.
#
# The keys of the dictionary will be `player_id` and values will be dictionaries containing each player's variables (from question 1).
#
# Construct the `players` dictionary and insert the player that you defined in question 1, then print `players`.

# %%
# Passing class instance attributes to playerlist dictionary. 

playerlist = { 1:
               {'player_name':player1.player_name,
                'time_played':player1.time_played,
                'player_pokemon':player1.player_pokemon,
                'gym_visited':player1.gym_visited
               },
               3:
               {'player_name':player3.player_name,
                'time_played':player3.time_played,
                'player_pokemon':player3.player_pokemon,
                'gym_visited':player3.gym_visited
               },
               4:
               {'player_name':player4.player_name,
                'time_played':player4.time_played,
                'player_pokemon':player4.player_pokemon,
                'gym_visited':player4.gym_visited
               }             
             }

# %%
# Calling class method 'summary' to display playerlist dictionary. Reference back to section 1 for its class function definition.

player.summary()
# Out:
#  Player 1 :
# {'gym_visited': ['sporcle.com', 'linkedin.com'],
#  'player_name': 'Vincent',
#  'player_pokemon': {},
#  'time_played': 88.8}
#
#
#
#  Player 3 :
# {'gym_visited': ['twitter.com', 'github.com'],
#  'player_name': 'Diane',
#  'player_pokemon': {},
#  'time_played': 36.9}
#
#
#
#  Player 4 :
# {'gym_visited': ['ebay.com', 'stackoverflow.com'],
#  'player_name': 'Timmy',
#  'player_pokemon': {},
#  'time_played': 124.6}

# %% [markdown]
# ---
#
# ### 4.2
#
# Create a new player with `player_id = 2` in the `players` dictionary. Leave the `'player_pokemon'` dictionary empty. Append `'alcatraz'` and `'pacific_beach'` to the `'gyms_visited'` list for player 2.
#
# The `'player_name'` and `'time_played'` values are up to you, but must be a string and float, respectively.
#
# Remember, the player_id is the key for the player in the players dictionary.
#
# Print the `players` dictionary with the new player inserted.
#
# playerlist['2']='alcatraz',111,{'pacific_beach'},[2,1]

# %%
player2 = Player() 
player2.add_new_player(2,'Edoardo',111,{},['alcatraz','pacific_beach'])
playerlist2 = { 2:
               {'player_name':player2.player_name,
                'time_played':player2.time_played,
                'player_pokemon':player2.player_pokemon,
                'gym_visited':player2.gym_visited
               }
             }
# Out:
# Initializing new instance for a new player

# %%
# Adding playerlist2 dict to original main playerlist

playerlist.update(playerlist2)
pprint.pprint(playerlist)        # display player dictionary using pprint
player.summary()                 # display player using class method.
# Out:
# {1: {'gym_visited': ['sporcle.com', 'linkedin.com'],
#      'player_name': 'Vincent',
#      'player_pokemon': {},
#      'time_played': 88.8},
#  2: {'gym_visited': ['alcatraz', 'pacific_beach'],
#      'player_name': 'Edoardo',
#      'player_pokemon': {},
#      'time_played': 111},
#  3: {'gym_visited': ['twitter.com', 'github.com'],
#      'player_name': 'Diane',
#      'player_pokemon': {},
#      'time_played': 36.9},
#  4: {'gym_visited': ['ebay.com', 'stackoverflow.com'],
#      'player_name': 'Timmy',
#      'player_pokemon': {},
#      'time_played': 124.6}}
#
#  Player 1 :
# {'gym_visited': ['sporcle.com', 'linkedin.com'],
#  'player_name': 'Vincent',
#  'player_pokemon': {},
#  'time_played': 88.8}
#
#
#
#  Player 3 :
# {'gym_visited': ['twitter.com', 'github.com'],
#  'player_name': 'Diane',
#  'player_pokemon': {},
#  'time_played': 36.9}
#
#
#
#  Player 4 :
# {'gym_visited': ['ebay.com', 'stackoverflow.com'],
#  'player_name': 'Timmy',
#  'player_pokemon': {},
# ...

# %%
#display player stat using class method for instance attribute.

player1.print_player_stat()
player2.print_player_stat()
player3.print_player_stat()
player4.print_player_stat()
# Out:
# Player_ID: 1
# Player_Name: Vincent
# Player_Time_Played: 88.8
# Player_Pokemon: {}
# Player_Gym_Visited: ['sporcle.com', 'linkedin.com']
#
#
# Player_ID: 2
# Player_Name: Edoardo
# Player_Time_Played: 111
# Player_Pokemon: {}
# Player_Gym_Visited: ['alcatraz', 'pacific_beach']
#
#
# Player_ID: 3
# Player_Name: Diane
# Player_Time_Played: 36.9
# Player_Pokemon: {}
# Player_Gym_Visited: ['twitter.com', 'github.com']
#
#
# Player_ID: 4
# Player_Name: Timmy
# Player_Time_Played: 124.6
# Player_Pokemon: {}
# Player_Gym_Visited: ['ebay.com', 'stackoverflow.com']

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 5. Add captured pokemon for each player
#
# ---
#
# The `'player_pokemon'` keyed dictionaries for each player keep track of which of the pokemon each player has.
#
# The keys of the `'player_pokemon'` dictionaries are the pokemon ids that correspond to the ids in the `pokedex` dictionary you created earlier. The values are integers specifying the stats for the pokemon.
#
# Give player 1 a squirtle. Give player 2 charmander and a bulbasaur.
#
# Print the players dictionary after adding the pokemon for each player.

# %%
# Playerlist dict update with pokemon dict update  

for keys,values in playerlist.items():
    if values['player_name'] == "Vincent":
        values['player_pokemon']= "squirtle" 
    elif values['player_name'] == "Edoardo":
        values['player_pokemon']= "charmander" 
    elif values['player_name'] == "Diane":
        values['player_pokemon']= "bulbasaur"  
        
player.summary()
# Out:
#  Player 1 :
# {'gym_visited': ['sporcle.com', 'linkedin.com'],
#  'player_name': 'Vincent',
#  'player_pokemon': 'squirtle',
#  'time_played': 88.8}
#
#
#
#  Player 3 :
# {'gym_visited': ['twitter.com', 'github.com'],
#  'player_name': 'Diane',
#  'player_pokemon': 'bulbasaur',
#  'time_played': 36.9}
#
#
#
#  Player 4 :
# {'gym_visited': ['ebay.com', 'stackoverflow.com'],
#  'player_name': 'Timmy',
#  'player_pokemon': {},
#  'time_played': 124.6}
#
#
#
#  Player 2 :
# {'gym_visited': ['alcatraz', 'pacific_beach'],
#  'player_name': 'Edoardo',
#  'player_pokemon': 'charmander',
#  'time_played': 111}

# %%
# Class objects instances also need to be updated - with pokemon attribute:

for keys,values in pokedex.items():
    if values['name'] == "squirtle":
        player1.player_pokemon={keys:values['name']} 

for keys,values in pokedex.items():
    if values['name'] == "charmander":
        player2.player_pokemon={keys:values['name']} 
        
for keys,values in pokedex.items():
    if values['name'] == "bulbasaur":
        player3.player_pokemon={keys:values['name']}

# %%
for keys,values in player1.player_pokemon.items():
    print("Player1: ", player1.player_name) 
    pprint.pprint(values) 
    print('\n') 
    
for keys,values in player2.player_pokemon.items():
    print("Player2: ", player2.player_name) 
    pprint.pprint(values) 
    print('\n') 
    
for keys,values in player3.player_pokemon.items():
    print("Player3: ", player3.player_name) 
    pprint.pprint(values)
# Out:
# Player1:  Vincent
# 'squirtle'
#
#
# Player2:  Edoardo
# 'charmander'
#
#
# Player3:  Diane
# 'bulbasaur'

# %% [markdown]
# ## 6. What gyms have players visited?
#
# ---
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
# ### 6.1
#
# Write a for-loop that:
#
# 1. Iterates through the `pokemon_gyms` list of gym locations you defined before.
# 2. For each gym, iterate through each player in the `players` dictionary with a second, internal for-loop.
# 3. If the player has visited the gym, print out "[player] has visited [gym location].", filling in [player] and [gym location] with the current player's name and current gym location.

# %%
for gym in gyms:
    pprint.pprint (gym)
# Out:
# 'reddit.com'
# 'amazon.com'
# 'twitter.com'
# 'linkedin.com'
# 'ebay.com'
# 'netflix.com'
# 'sporcle.com'
# 'stackoverflow.com'
# 'github.com'
# 'quora.com'

# %%
for gym in gyms:
    print(gym.capitalize(),'\n')    
    for keys,values in playerlist.items():
        if gym in values['gym_visited']:
            print('\t', values['player_name'], 'has visited', gym, '\n')
# Out:
# Reddit.com
#
# Amazon.com
#
# Twitter.com
#
# 	 Diane has visited twitter.com
#
# Linkedin.com
#
# 	 Vincent has visited linkedin.com
#
# Ebay.com
#
# 	 Timmy has visited ebay.com
#
# Netflix.com
#
# Sporcle.com
#
# 	 Vincent has visited sporcle.com
#
# Stackoverflow.com
#
# 	 Timmy has visited stackoverflow.com
#
# Github.com
#
# 	 Diane has visited github.com
#
# Quora.com

# %% [markdown]
# <img src="http://imgur.com/xDpSobf.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
# ### 6.2
#
# How many times did that loop run? If you have N gyms and also N players, how many times would it run as a function of N?
#
# Can you think of a more efficient way to accomplish the same thing?
#
# (You can write your answer as Markdown text.)

# %% [markdown]
# N x N times
# While loop is more efficient because it simply repeats a set of statements as long as the loop expression is True.
# So in this case, we know that both 'alcatraz' and 'pacific_beach' are not in the list of 10 websites.
# We can write our code to skip these strings for comparison.

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 7. Calculate player "power".
#
# ---
#
# Define a function that will calculate a player's "power". Player power is defined as the sum of the base statistics all of their pokemon.
#
# Your function will:
#
# 1. Accept the `players` dictionary, `pokedex` dictionary, and a player_id as arguments.
# 2. For the specified player_id, look up that player's pokemon and their level(s).
# 3. Find and aggregate the attack and defense values for each of the player's pokemon from the `pokedex` dictionary.
# 4. Print "[player name]'s power is [player power].", where the player power is the sum of the base statistics for all of their pokemon.
# 5. Return the player's power value.
#
# Print out the pokemon power for each of your players.

# %%
# Function to calculate player power
def power (playerlist, pokedex, id):
    for keys,values in playerlist.items():
        while keys==id:    # when key is similar to the ID enter:
            playerpokemon = values['player_pokemon']   
            print('\nPlayer Name:', values['player_name'], '\nPokemon:',playerpokemon)  
            for keys,values in pokedex.items():
                if playerpokemon == values['name']:      # when player's pokemon is in the value of pokemon dict 
                    power = values['attack']+values['defense']    # Add to find power
                    print('Player Power:', power)    
    return (power)

# %%
power(playerlist, pokedex, 1)
# Out:
# Player Name: Vincent
# Pokemon: squirtle
# Player Power: 202
# 202

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 8. Load a pokedex file containing all the pokemon
#
# ---
#
# ### 8.1
#
# While you were putting together the prototype code, your colleagues were preparing a dataset of Pokemon and their attributes. (This was a rush job, so they may have picked some crazy values for some...)
#
# The code below loads information from a comma separated value (csv) file. You need to parse this string into a more useable format. The format of the string is:
#
# - Rows are separated by newline characters: \n
# - Columns are separated by commas: ,
# - All cells in the csv are double quoted. Ex: "PokedexNumber" is the first cell of the first row.
#
#
# Using for-loops, create a list of lists where each list within the overall list is a row of the csv/matrix, and each element in that list is a cell in that row. Additional criteria:
#
# 1. Quotes are removed from each cell item.
# 2. Numeric column values are converted to floats.
# 3. There are some cells that are empty and have no information. For these cells put a -1 value in place.
#
# Your end result is effectively a matrix. Each list in the outer list is a row, and the *j*th elements of list together form the *j*th column, which represents a data attribute. The first three lists in your pokedex list should look like this:
#
#     ['PokedexNumber', 'Name', 'Type', 'Total', 'HP', 'Attack', 'Defense', 'SpecialAttack', 'SpecialDefense', 'Speed']
#     [1.0, 'Bulbasaur', 'GrassPoison', 318.0, 45.0, 49.0, 49.0, 65.0, 65.0, 45.0]
#     [2.0, 'Ivysaur', 'GrassPoison', 405.0, 60.0, 62.0, 63.0, 80.0, 80.0, 60.0]

# %%
# Code to read in pokedex info
raw_pd = ''
pokedex_file = 'pokedex_basic.csv'
with open(pokedex_file, 'r') as f:
    raw_pd = f.read()    
# the pokedex string is assigned to the raw_pd variable
clean1 = raw_pd.splitlines()

# %%
# for looping to convert the data from string to list by splitting the word.
data_unclean=[]
for row in clean1:
    data_unclean.append(row.split(','))

# %%
# for looping to remove double quotations    
data_clean=[]
for row in data_unclean:  # for each rows
    temp_data=[]          # temp store for append each word back into a list
    for item in row:      # for each item in a row
        temp_data.append(item.replace('"',''))
    data_clean.append(temp_data)   # append each temp list back into the main list.

# %%
header=data_clean[0]
data=data_clean[1:]

# %%
# for looping to convert to float and assign -1 to empty cells
data_clean_final=[] 
for row in data:        # for each row
    temp1_data=[]       # temp store for append each word back into a list
    for item in row:    # for items in a row
        try:
            temp1_data.append(float(item))     # try convert to float if fail go to except
        except:
            if item == "":                     # try to assign -1 if empty
                temp1_data.append(-1)
            else:
                temp1_data.append(item)        # else append orginal word back without change.
    data_clean_final.append(temp1_data)        # append each temp list back into the main list.

# %%
header
data_clean_final[0:10]
# Out:
# [[1.0, 'Bulbasaur', 'GrassPoison', 318.0, 45.0, 49.0, 49.0, 65.0, 65.0, 45.0],
#  [2.0, 'Ivysaur', 'GrassPoison', 405.0, 60.0, 62.0, 63.0, 80.0, 80.0, 60.0],
#  [3.0, 'Venusaur', 'GrassPoison', 525.0, 80.0, 82.0, 83.0, 100.0, 100.0, 80.0],
#  [3.0,
#   'VenusaurMega Venusaur',
#   'GrassPoison',
#   625.0,
#   80.0,
#   100.0,
#   123.0,
#   122.0,
#   120.0,
#   80.0],
#  [4.0, 'Charmander', 'Fire', 309.0, 39.0, 52.0, 43.0, 60.0, 50.0, 65.0],
#  [5.0, 'Charmeleon', 'Fire', 405.0, 58.0, 64.0, 58.0, 80.0, 65.0, 80.0],
#  [6.0, 'Charizard', 'FireFlying', 534.0, 78.0, 84.0, 78.0, 109.0, 85.0, 100.0],
#  [6.0,
#   'CharizardMega Charizard X',
#   'FireDragon',
#   634.0,
#   78.0,
#   130.0,
#   111.0,
#   130.0,
#   85.0,
#   100.0],
#  [6.0,
#   'CharizardMega Charizard Y',
#   'FireFlying',
#   634.0,
#   78.0,
#   104.0,
#   78.0,
#   159.0,
#   115.0,
#   100.0],
#  [7.0, 'Squirtle', 'Water', 314.0, 44.0, 48.0, 65.0, 50.0, 64.0, 43.0]]

# %% [markdown]
# <img src="http://imgur.com/xDpSobf.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ### 8.2 Parse the raw pokedex with list comprehensions
#
# ---
#
# Perform the same parsing as above, but **using only a single list comprehension** instead of for loops. You may have nested list comprehensions within the main list comprehension! The output should be exactly the same.

# %%
[[c for c in k] for k in raw_pd]

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 9. Write a function to generate the full pokedex
#
# ---
#
# Write a function that recreates the pokedex you made before, but with the data read in from the full pokemon file. The `PokedexNumber` should be used as the `pokemon_id` key values for the dictionary of pokemon.
#
# Your function should:
#
# 1. Take the parsed pokedex information you created above as an argument.
# 2. Return a dictionary in the same format as your original pokedex you created before containing the information from the parsed full pokedex file.
#
# To test the function, print out the pokemon with id = 100.

# %%
def full_pokedex(header,pokedexlist,ID):
    length = len(data_clean_final) # Total count of Pokemon
    title=''
    n=0
    poke_dict={}      # set a empty dict   
    
    for rows in data_clean_final:          # for each data row  
        for i, items in enumerate(rows):   # for each items in a row 
            key=(rows[0]) 
            poke_dict[str(key)]=items
            
#    for keys,values in poke_dict.items():
#        if values['PokedexNumber'] == ID:
#            print("PokedexNumber: ", ID, "has power:" values['total']) 
    
    return (poke_dict)

# %%
full_pokedex(header,data_clean_final,100)
# Out:
# {'1.0': 45.0,
#  '2.0': 60.0,
#  '3.0': 80.0,
#  '4.0': 65.0,
#  '5.0': 80.0,
#  '6.0': 100.0,
#  '7.0': 43.0,
#  '8.0': 58.0,
#  '9.0': 78.0,
#  '10.0': 45.0,
#  '11.0': 30.0,
#  '12.0': 70.0,
#  '13.0': 50.0,
#  '14.0': 35.0,
#  '15.0': 145.0,
#  '16.0': 56.0,
#  '17.0': 71.0,
#  '18.0': 121.0,
#  '19.0': 72.0,
#  '20.0': 97.0,
#  '21.0': 70.0,
#  '22.0': 100.0,
#  '23.0': 55.0,
#  '24.0': 80.0,
#  '25.0': 90.0,
#  '26.0': 110.0,
#  '27.0': 40.0,
#  '28.0': 65.0,
#  '29.0': 41.0,
#  '30.0': 56.0,
#  '31.0': 76.0,
#  '32.0': 50.0,
#  '33.0': 65.0,
#  '34.0': 85.0,
#  '35.0': 35.0,
#  '36.0': 60.0,
#  '37.0': 65.0,
#  '38.0': 100.0,
#  '39.0': 20.0,
#  '40.0': 45.0,
#  '41.0': 55.0,
#  '42.0': 90.0,
#  '43.0': 30.0,
#  '44.0': 40.0,
#  '45.0': 50.0,
#  '46.0': 25.0,
#  '47.0': 30.0,
#  '48.0': 45.0,
#  '49.0': 90.0,
#  '50.0': 95.0,
#  '51.0': 120.0,
#  '52.0': 90.0,
#  '53.0': 115.0,
#  '54.0': 55.0,
#  '55.0': 85.0,
#  '56.0': 70.0,
#  '57.0': 95.0,
#  '58.0': 60.0,
# ...

# %% [markdown]
# ####  For some reason, I only manage to get Pokemon ID : Speed value    ####

# %% [markdown]
# <img src="http://i.imgur.com/GCAf1UX.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 10. Write a function to generate a "filtered" pokedex
# ---
# Your function should:
# 1. Take the parsed pokedex information you created above as an argument.
# 1. Take a dictionary as a parameter with keys matching the features of the Pokedex, filtering by exact match for string type values, and/or filter continuous variables specified value that is greater than or equal to the dictionary key parameter.
# 1. Return multiple elements from the Pokedex
#
# Example:
#
# ```python
#
# # Only filter based on parameters passed
# filter_options = {
#     'Attack':   25,
#     'Defense':  30,
#     'Type':     'Electric'
# }
#
# # Return records with attack >= 24, defense >= 30, and type == "Electric"
# # Also anticipate that other paramters can also be passed such as "SpecialAttack", "Speed", etc.
# filtered_pokedex(pokedex_data, filter=filter_options)
#
# # Example output:
# # [{'Attack': 30.0,
# #  'Defense': 50.0,
# #  'HP': 40.0,
# #  'Name': 'Voltorb',
# #  'SpecialAttack': 55.0,
# #  'SpecialDefense': 55.0,
# #  'Speed': 100.0,
# #  'Total': 330.0,
# #  'Type': 'Electric'},
# #  {'Attack': 30.0,
# #  'Defense': 33.0,
# #  'HP': 32.0,
# #  'Name': 'Pikachu',
# #  'SpecialAttack': 55.0,
# #  'SpecialDefense': 55.0,
# #  'Speed': 100.0,
# #  'Total': 330.0,
# #  'Type': 'Electric'},
# #  ... etc
# #  ]
#
# ```

# %% [markdown]
# ## 9. Descriptive statistics on the prototype pokedex
#
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
# ### 9.1
#
# What is the population mean and standard deviation of the "Total" attribute for all characters in the Pokedex?

# %%
import numpy as np

####  To find the mean for each characters, sum up total attribute then divide by the total number of pokemon (721)  ####
####  Alternative there is mean function that can be used.   ####

for keys,values in poke_dict.items():
    mean = float(sum(values['total']/len(['total']))
                 
Or use
for keys,values in poke_dict.items():
    mean = np.mean(values['total'])

# Standard deviation can also be find using the std function.
                 
for keys,values in poke_dict.items():
    std = np.std(values['total'])

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
# ### 9.2
#
# The game is no fun if the characters are wildly unbalanced! Are any characters "overpowered", which we'll define as having a "Total" more than three standard deviations from the population mean?

# %% [markdown]
# <img src="http://imgur.com/xDpSobf.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 10. Calibrate the frequency of Pokemon
#
# The design team wants you to make the powerful Pokemon rare, and the weaklings more common. How would you set the probability $p_i$ of finding Pokemon *i* each time a player visits a gym?
#
# Write a function that takes in a Pokedex number and returns a value $p_i$ for that character.
#
# Hint: there are many ways you could do this. What do _you_ think makes sense? Start with simplifying assumptions: for example, you could assume that the probabilities of encountering any two Pokemon on one visit to a gym are independent of each other.
